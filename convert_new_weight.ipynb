# %%
from tqdm import tqdm

# %%
import struct
import numpy as np
from collections import OrderedDict


def load_dtype(fp):
    v = struct.unpack("B", fp.read(1))[0]
    if v == 0:
        return np.int8
    elif v == 1:
        return np.float16
    elif v == 2:
        return np.float32
    else:
        raise TypeError("Unknown dtype %d" % v)

def load_string(fp):
    size = struct.unpack("I", fp.read(4))[0]
    v = fp.read(size)
    return v.decode("utf-8")

def load_tuple(fp):
    dim_tuple = struct.unpack("B", fp.read(1))[0]
    ret = []
    for _ in range(dim_tuple):
        ret.append(struct.unpack("I", fp.read(4))[0]) 
    return tuple(ret)

def load_parameter(fp):    
    shape = load_tuple(fp)
    value_size = struct.unpack("I", fp.read(4))[0]
    dtype = load_dtype(fp)
    value = fp.read(value_size)
    return shape, value, dtype

def load(fp, parent_name=''):
    num_parameters, num_sub_layers = struct.unpack("II", fp.read(8))
    parameters = []

    for _ in range(num_parameters):
        name = load_string(fp)
        shape, value, dtype = load_parameter(fp)
        parameters.append((parent_name + '.' + name, np.frombuffer(value, dtype).reshape(shape)))
    for _ in range(num_sub_layers):
        name = load_string(fp)
        parameters += load(fp, parent_name + '.' + name)
    return parameters

# %%
with open('../zhiyuan/cpm/checkpoint.pt', 'rb') as fp:
    parameters = load(fp)

# %%
pindex = {x[0]: x[1] for x in parameters}

# %%
npara = {}
for name, value in tqdm(parameters):
    if '_scale' not in name:
        has_scale = name + '_scale'
        if has_scale in pindex:
            scale = pindex[has_scale]
            value = value.astype(np.float16) * scale
        npara[name] = value
# Out:
# 100%|██████████| 516/516 [00:42<00:00, 12.03it/s]

# %%
for k, v in npara.items():
    print(k, v.shape)
# Out:
# .input_embedding.weight (30000, 2560)
# .position_embedding.weight (1024, 2560)
# .layers.0.layer_nrom_before_self_attn.weight (2560,)
# .layers.0.layer_nrom_before_self_attn.bias (2560,)
# .layers.0.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.0.self_attention.w_project_bias (3, 2560)
# .layers.0.self_attention.w_out (2560, 2560)
# .layers.0.self_attention.w_out_bias (2560,)
# .layers.0.layer_nrom_before_ff.weight (2560,)
# .layers.0.layer_nrom_before_ff.bias (2560,)
# .layers.0.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.0.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.0.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.0.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.1.layer_nrom_before_self_attn.weight (2560,)
# .layers.1.layer_nrom_before_self_attn.bias (2560,)
# .layers.1.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.1.self_attention.w_project_bias (3, 2560)
# .layers.1.self_attention.w_out (2560, 2560)
# .layers.1.self_attention.w_out_bias (2560,)
# .layers.1.layer_nrom_before_ff.weight (2560,)
# .layers.1.layer_nrom_before_ff.bias (2560,)
# .layers.1.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.1.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.1.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.1.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.2.layer_nrom_before_self_attn.weight (2560,)
# .layers.2.layer_nrom_before_self_attn.bias (2560,)
# .layers.2.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.2.self_attention.w_project_bias (3, 2560)
# .layers.2.self_attention.w_out (2560, 2560)
# .layers.2.self_attention.w_out_bias (2560,)
# .layers.2.layer_nrom_before_ff.weight (2560,)
# .layers.2.layer_nrom_before_ff.bias (2560,)
# .layers.2.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.2.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.2.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.2.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.3.layer_nrom_before_self_attn.weight (2560,)
# .layers.3.layer_nrom_before_self_attn.bias (2560,)
# .layers.3.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.3.self_attention.w_project_bias (3, 2560)
# .layers.3.self_attention.w_out (2560, 2560)
# .layers.3.self_attention.w_out_bias (2560,)
# .layers.3.layer_nrom_before_ff.weight (2560,)
# .layers.3.layer_nrom_before_ff.bias (2560,)
# .layers.3.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.3.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.3.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.3.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.4.layer_nrom_before_self_attn.weight (2560,)
# .layers.4.layer_nrom_before_self_attn.bias (2560,)
# .layers.4.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.4.self_attention.w_project_bias (3, 2560)
# .layers.4.self_attention.w_out (2560, 2560)
# .layers.4.self_attention.w_out_bias (2560,)
# .layers.4.layer_nrom_before_ff.weight (2560,)
# .layers.4.layer_nrom_before_ff.bias (2560,)
# .layers.4.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.4.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.4.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.4.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.5.layer_nrom_before_self_attn.weight (2560,)
# .layers.5.layer_nrom_before_self_attn.bias (2560,)
# .layers.5.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.5.self_attention.w_project_bias (3, 2560)
# .layers.5.self_attention.w_out (2560, 2560)
# .layers.5.self_attention.w_out_bias (2560,)
# .layers.5.layer_nrom_before_ff.weight (2560,)
# .layers.5.layer_nrom_before_ff.bias (2560,)
# .layers.5.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.5.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.5.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.5.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.6.layer_nrom_before_self_attn.weight (2560,)
# .layers.6.layer_nrom_before_self_attn.bias (2560,)
# .layers.6.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.6.self_attention.w_project_bias (3, 2560)
# .layers.6.self_attention.w_out (2560, 2560)
# .layers.6.self_attention.w_out_bias (2560,)
# .layers.6.layer_nrom_before_ff.weight (2560,)
# .layers.6.layer_nrom_before_ff.bias (2560,)
# .layers.6.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.6.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.6.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.6.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.7.layer_nrom_before_self_attn.weight (2560,)
# .layers.7.layer_nrom_before_self_attn.bias (2560,)
# .layers.7.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.7.self_attention.w_project_bias (3, 2560)
# .layers.7.self_attention.w_out (2560, 2560)
# .layers.7.self_attention.w_out_bias (2560,)
# .layers.7.layer_nrom_before_ff.weight (2560,)
# .layers.7.layer_nrom_before_ff.bias (2560,)
# .layers.7.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.7.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.7.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.7.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.8.layer_nrom_before_self_attn.weight (2560,)
# .layers.8.layer_nrom_before_self_attn.bias (2560,)
# .layers.8.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.8.self_attention.w_project_bias (3, 2560)
# .layers.8.self_attention.w_out (2560, 2560)
# .layers.8.self_attention.w_out_bias (2560,)
# .layers.8.layer_nrom_before_ff.weight (2560,)
# .layers.8.layer_nrom_before_ff.bias (2560,)
# .layers.8.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.8.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.8.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.8.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.9.layer_nrom_before_self_attn.weight (2560,)
# .layers.9.layer_nrom_before_self_attn.bias (2560,)
# .layers.9.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.9.self_attention.w_project_bias (3, 2560)
# .layers.9.self_attention.w_out (2560, 2560)
# .layers.9.self_attention.w_out_bias (2560,)
# .layers.9.layer_nrom_before_ff.weight (2560,)
# .layers.9.layer_nrom_before_ff.bias (2560,)
# .layers.9.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.9.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.9.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.9.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.10.layer_nrom_before_self_attn.weight (2560,)
# .layers.10.layer_nrom_before_self_attn.bias (2560,)
# .layers.10.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.10.self_attention.w_project_bias (3, 2560)
# .layers.10.self_attention.w_out (2560, 2560)
# .layers.10.self_attention.w_out_bias (2560,)
# .layers.10.layer_nrom_before_ff.weight (2560,)
# .layers.10.layer_nrom_before_ff.bias (2560,)
# .layers.10.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.10.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.10.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.10.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.11.layer_nrom_before_self_attn.weight (2560,)
# .layers.11.layer_nrom_before_self_attn.bias (2560,)
# .layers.11.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.11.self_attention.w_project_bias (3, 2560)
# .layers.11.self_attention.w_out (2560, 2560)
# .layers.11.self_attention.w_out_bias (2560,)
# .layers.11.layer_nrom_before_ff.weight (2560,)
# .layers.11.layer_nrom_before_ff.bias (2560,)
# .layers.11.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.11.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.11.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.11.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.12.layer_nrom_before_self_attn.weight (2560,)
# .layers.12.layer_nrom_before_self_attn.bias (2560,)
# .layers.12.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.12.self_attention.w_project_bias (3, 2560)
# .layers.12.self_attention.w_out (2560, 2560)
# .layers.12.self_attention.w_out_bias (2560,)
# .layers.12.layer_nrom_before_ff.weight (2560,)
# .layers.12.layer_nrom_before_ff.bias (2560,)
# .layers.12.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.12.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.12.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.12.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.13.layer_nrom_before_self_attn.weight (2560,)
# .layers.13.layer_nrom_before_self_attn.bias (2560,)
# .layers.13.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.13.self_attention.w_project_bias (3, 2560)
# .layers.13.self_attention.w_out (2560, 2560)
# .layers.13.self_attention.w_out_bias (2560,)
# .layers.13.layer_nrom_before_ff.weight (2560,)
# .layers.13.layer_nrom_before_ff.bias (2560,)
# .layers.13.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.13.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.13.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.13.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.14.layer_nrom_before_self_attn.weight (2560,)
# .layers.14.layer_nrom_before_self_attn.bias (2560,)
# .layers.14.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.14.self_attention.w_project_bias (3, 2560)
# .layers.14.self_attention.w_out (2560, 2560)
# .layers.14.self_attention.w_out_bias (2560,)
# .layers.14.layer_nrom_before_ff.weight (2560,)
# .layers.14.layer_nrom_before_ff.bias (2560,)
# .layers.14.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.14.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.14.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.14.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.15.layer_nrom_before_self_attn.weight (2560,)
# .layers.15.layer_nrom_before_self_attn.bias (2560,)
# .layers.15.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.15.self_attention.w_project_bias (3, 2560)
# .layers.15.self_attention.w_out (2560, 2560)
# .layers.15.self_attention.w_out_bias (2560,)
# .layers.15.layer_nrom_before_ff.weight (2560,)
# .layers.15.layer_nrom_before_ff.bias (2560,)
# .layers.15.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.15.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.15.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.15.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.16.layer_nrom_before_self_attn.weight (2560,)
# .layers.16.layer_nrom_before_self_attn.bias (2560,)
# .layers.16.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.16.self_attention.w_project_bias (3, 2560)
# .layers.16.self_attention.w_out (2560, 2560)
# .layers.16.self_attention.w_out_bias (2560,)
# .layers.16.layer_nrom_before_ff.weight (2560,)
# .layers.16.layer_nrom_before_ff.bias (2560,)
# .layers.16.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.16.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.16.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.16.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.17.layer_nrom_before_self_attn.weight (2560,)
# .layers.17.layer_nrom_before_self_attn.bias (2560,)
# .layers.17.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.17.self_attention.w_project_bias (3, 2560)
# .layers.17.self_attention.w_out (2560, 2560)
# .layers.17.self_attention.w_out_bias (2560,)
# .layers.17.layer_nrom_before_ff.weight (2560,)
# .layers.17.layer_nrom_before_ff.bias (2560,)
# .layers.17.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.17.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.17.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.17.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.18.layer_nrom_before_self_attn.weight (2560,)
# .layers.18.layer_nrom_before_self_attn.bias (2560,)
# .layers.18.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.18.self_attention.w_project_bias (3, 2560)
# .layers.18.self_attention.w_out (2560, 2560)
# .layers.18.self_attention.w_out_bias (2560,)
# .layers.18.layer_nrom_before_ff.weight (2560,)
# .layers.18.layer_nrom_before_ff.bias (2560,)
# .layers.18.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.18.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.18.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.18.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.19.layer_nrom_before_self_attn.weight (2560,)
# .layers.19.layer_nrom_before_self_attn.bias (2560,)
# .layers.19.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.19.self_attention.w_project_bias (3, 2560)
# .layers.19.self_attention.w_out (2560, 2560)
# .layers.19.self_attention.w_out_bias (2560,)
# .layers.19.layer_nrom_before_ff.weight (2560,)
# .layers.19.layer_nrom_before_ff.bias (2560,)
# .layers.19.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.19.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.19.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.19.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.20.layer_nrom_before_self_attn.weight (2560,)
# .layers.20.layer_nrom_before_self_attn.bias (2560,)
# .layers.20.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.20.self_attention.w_project_bias (3, 2560)
# .layers.20.self_attention.w_out (2560, 2560)
# .layers.20.self_attention.w_out_bias (2560,)
# .layers.20.layer_nrom_before_ff.weight (2560,)
# .layers.20.layer_nrom_before_ff.bias (2560,)
# .layers.20.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.20.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.20.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.20.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.21.layer_nrom_before_self_attn.weight (2560,)
# .layers.21.layer_nrom_before_self_attn.bias (2560,)
# .layers.21.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.21.self_attention.w_project_bias (3, 2560)
# .layers.21.self_attention.w_out (2560, 2560)
# .layers.21.self_attention.w_out_bias (2560,)
# .layers.21.layer_nrom_before_ff.weight (2560,)
# .layers.21.layer_nrom_before_ff.bias (2560,)
# .layers.21.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.21.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.21.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.21.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.22.layer_nrom_before_self_attn.weight (2560,)
# .layers.22.layer_nrom_before_self_attn.bias (2560,)
# .layers.22.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.22.self_attention.w_project_bias (3, 2560)
# .layers.22.self_attention.w_out (2560, 2560)
# .layers.22.self_attention.w_out_bias (2560,)
# .layers.22.layer_nrom_before_ff.weight (2560,)
# .layers.22.layer_nrom_before_ff.bias (2560,)
# .layers.22.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.22.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.22.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.22.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.23.layer_nrom_before_self_attn.weight (2560,)
# .layers.23.layer_nrom_before_self_attn.bias (2560,)
# .layers.23.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.23.self_attention.w_project_bias (3, 2560)
# .layers.23.self_attention.w_out (2560, 2560)
# .layers.23.self_attention.w_out_bias (2560,)
# .layers.23.layer_nrom_before_ff.weight (2560,)
# .layers.23.layer_nrom_before_ff.bias (2560,)
# .layers.23.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.23.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.23.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.23.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.24.layer_nrom_before_self_attn.weight (2560,)
# .layers.24.layer_nrom_before_self_attn.bias (2560,)
# .layers.24.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.24.self_attention.w_project_bias (3, 2560)
# .layers.24.self_attention.w_out (2560, 2560)
# .layers.24.self_attention.w_out_bias (2560,)
# .layers.24.layer_nrom_before_ff.weight (2560,)
# .layers.24.layer_nrom_before_ff.bias (2560,)
# .layers.24.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.24.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.24.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.24.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.25.layer_nrom_before_self_attn.weight (2560,)
# .layers.25.layer_nrom_before_self_attn.bias (2560,)
# .layers.25.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.25.self_attention.w_project_bias (3, 2560)
# .layers.25.self_attention.w_out (2560, 2560)
# .layers.25.self_attention.w_out_bias (2560,)
# .layers.25.layer_nrom_before_ff.weight (2560,)
# .layers.25.layer_nrom_before_ff.bias (2560,)
# .layers.25.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.25.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.25.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.25.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.26.layer_nrom_before_self_attn.weight (2560,)
# .layers.26.layer_nrom_before_self_attn.bias (2560,)
# .layers.26.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.26.self_attention.w_project_bias (3, 2560)
# .layers.26.self_attention.w_out (2560, 2560)
# .layers.26.self_attention.w_out_bias (2560,)
# .layers.26.layer_nrom_before_ff.weight (2560,)
# .layers.26.layer_nrom_before_ff.bias (2560,)
# .layers.26.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.26.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.26.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.26.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.27.layer_nrom_before_self_attn.weight (2560,)
# .layers.27.layer_nrom_before_self_attn.bias (2560,)
# .layers.27.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.27.self_attention.w_project_bias (3, 2560)
# .layers.27.self_attention.w_out (2560, 2560)
# .layers.27.self_attention.w_out_bias (2560,)
# .layers.27.layer_nrom_before_ff.weight (2560,)
# .layers.27.layer_nrom_before_ff.bias (2560,)
# .layers.27.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.27.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.27.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.27.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.28.layer_nrom_before_self_attn.weight (2560,)
# .layers.28.layer_nrom_before_self_attn.bias (2560,)
# .layers.28.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.28.self_attention.w_project_bias (3, 2560)
# .layers.28.self_attention.w_out (2560, 2560)
# .layers.28.self_attention.w_out_bias (2560,)
# .layers.28.layer_nrom_before_ff.weight (2560,)
# .layers.28.layer_nrom_before_ff.bias (2560,)
# .layers.28.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.28.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.28.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.28.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.29.layer_nrom_before_self_attn.weight (2560,)
# .layers.29.layer_nrom_before_self_attn.bias (2560,)
# .layers.29.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.29.self_attention.w_project_bias (3, 2560)
# .layers.29.self_attention.w_out (2560, 2560)
# .layers.29.self_attention.w_out_bias (2560,)
# .layers.29.layer_nrom_before_ff.weight (2560,)
# .layers.29.layer_nrom_before_ff.bias (2560,)
# .layers.29.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.29.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.29.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.29.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.30.layer_nrom_before_self_attn.weight (2560,)
# .layers.30.layer_nrom_before_self_attn.bias (2560,)
# .layers.30.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.30.self_attention.w_project_bias (3, 2560)
# .layers.30.self_attention.w_out (2560, 2560)
# .layers.30.self_attention.w_out_bias (2560,)
# .layers.30.layer_nrom_before_ff.weight (2560,)
# .layers.30.layer_nrom_before_ff.bias (2560,)
# .layers.30.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.30.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.30.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.30.dense_gelu_dense.wo.weight_bias (2560,)
# .layers.31.layer_nrom_before_self_attn.weight (2560,)
# .layers.31.layer_nrom_before_self_attn.bias (2560,)
# .layers.31.self_attention.w_project_qkv (3, 2560, 2560)
# .layers.31.self_attention.w_project_bias (3, 2560)
# .layers.31.self_attention.w_out (2560, 2560)
# .layers.31.self_attention.w_out_bias (2560,)
# .layers.31.layer_nrom_before_ff.weight (2560,)
# .layers.31.layer_nrom_before_ff.bias (2560,)
# .layers.31.dense_gelu_dense.wi.weight (10240, 2560)
# .layers.31.dense_gelu_dense.wi.weight_bias (10240,)
# .layers.31.dense_gelu_dense.wo.weight (2560, 10240)
# .layers.31.dense_gelu_dense.wo.weight_bias (2560,)
# .encoder_final_layer_nrom.weight (2560,)
# .encoder_final_layer_nrom.bias (2560,)

# %%
def get_layer(n):
    rets = {}
    for k, v in npara.items():
        if f'.layers.{n}.' in k:
            rets[k] = v
    weights = [
        np.transpose(rets[f'.layers.{n}.self_attention.w_project_qkv'][0]),
        rets[f'.layers.{n}.self_attention.w_project_bias'][0],
        np.transpose(rets[f'.layers.{n}.self_attention.w_project_qkv'][1]),
        rets[f'.layers.{n}.self_attention.w_project_bias'][1],
        np.transpose(rets[f'.layers.{n}.self_attention.w_project_qkv'][2]),
        rets[f'.layers.{n}.self_attention.w_project_bias'][2],
        np.transpose(rets[f'.layers.{n}.self_attention.w_out']),
        rets[f'.layers.{n}.self_attention.w_out_bias'],
        rets[f'.layers.{n}.layer_nrom_before_self_attn.weight'],
        rets[f'.layers.{n}.layer_nrom_before_self_attn.bias'],
        rets[f'.layers.{n}.layer_nrom_before_ff.weight'],
        rets[f'.layers.{n}.layer_nrom_before_ff.bias'],
        np.transpose(rets[f'.layers.{n}.dense_gelu_dense.wi.weight']),
        rets[f'.layers.{n}.dense_gelu_dense.wi.weight_bias'],
        np.transpose(rets[f'.layers.{n}.dense_gelu_dense.wo.weight']),
        rets[f'.layers.{n}.dense_gelu_dense.wo.weight_bias'],
    ]
    
    return weights

# %%
weights = [
    npara['.input_embedding.weight'],
    npara['.position_embedding.weight'],
]
for i in range(32):
    weights += get_layer(i)
weights += [
    npara['.encoder_final_layer_nrom.weight'],
    npara['.encoder_final_layer_nrom.bias'],
]

# %%
len(weights)
# Out:
# 516

# %%
import re

import torch
import numpy as np
import tensorflow as tf

from tf2gpt.model import GPT

# %%
gpt = GPT(
    vocab_size=30_000,
    layer_size=32,
    block_size=1024,
    embedding_dropout=0.0,
    embedding_size=2560,
    num_attention_heads=32,
    attention_dropout=0.0,
    residual_dropout=0.0)

# %%
gpt._set_inputs(
    tf.TensorSpec(shape=[None, None],
        dtype=tf.int32,
        name="input_ids"
    ))

# %%
print(gpt(tf.constant([[1]])).shape)
# Out:
# (1, 1, 30000)

# %%
for x in :
    if 'gpt/layer' in x.name:
        if 'gpt/layer00' in x.name:
            print(x.name, x.shape)
    else:
        print(x.name, x.shape)
# Out:
# gpt/embedding/embeddings:0 (30000, 2560)
# position_embeddings:0 (1024, 2560)
# gpt/layer00/attention/query_layer/kernel:0 (2560, 2560)
# gpt/layer00/attention/query_layer/bias:0 (2560,)
# gpt/layer00/attention/key_layer/kernel:0 (2560, 2560)
# gpt/layer00/attention/key_layer/bias:0 (2560,)
# gpt/layer00/attention/value_layer/kernel:0 (2560, 2560)
# gpt/layer00/attention/value_layer/bias:0 (2560,)
# gpt/layer00/attention/context_projection_layer/kernel:0 (2560, 2560)
# gpt/layer00/attention/context_projection_layer/bias:0 (2560,)
# gpt/layer00/LayerNorm_mlp_ln0/gamma:0 (2560,)
# gpt/layer00/LayerNorm_mlp_ln0/beta:0 (2560,)
# gpt/layer00/LayerNorm_mlp_ln1/gamma:0 (2560,)
# gpt/layer00/LayerNorm_mlp_ln1/beta:0 (2560,)
# gpt/layer00/intermediate/kernel:0 (2560, 10240)
# gpt/layer00/intermediate/bias:0 (10240,)
# gpt/layer00/output/kernel:0 (10240, 2560)
# gpt/layer00/output/bias:0 (2560,)
# gpt/LayerNorm_final_norm/gamma:0 (2560,)
# gpt/LayerNorm_final_norm/beta:0 (2560,)

# %%
len(gpt.weights)
# Out:
# 516

# %%
gpt.set_weights(weights)

# %%
from gpt2_tokenizer import GPT2Tokenizer

# %%
cbpe = GPT2Tokenizer(
    'CPM-Generate/bpe_3w_new/vocab.json',
    'CPM-Generate/bpe_3w_new/merges.txt',
    model_file='CPM-Generate/bpe_3w_new/chinese_vocab.model')

# %%
ids = cbpe.encode('今天天气不错')

for i in range(10):
    output = gpt(tf.constant([ids]))
    nid = np.argmax(output[0, -1])
    ids += [nid]
    print(i, cbpe.decode(ids))
# Out:
# 0 今天天气 不错
# 1 今天天气 不错 ,
# 2 今天天气 不错 , 我
# 3 今天天气 不错 , 我 带
# 4 今天天气 不错 , 我 带你
# 5 今天天气 不错 , 我 带你去
# 6 今天天气 不错 , 我 带你去
# 7 今天天气 不错 , 我 带你去 个
# 8 今天天气 不错 , 我 带你去 个 地方
# 9 今天天气 不错 , 我 带你去 个 地方

# %%
gpt.save('cpm_saved_model')
# Out:
# WARNING:absl:Found untraced functions such as attention_layer_call_fn, attention_layer_call_and_return_conditional_losses, LayerNorm_mlp_ln0_layer_call_fn, LayerNorm_mlp_ln0_layer_call_and_return_conditional_losses, LayerNorm_mlp_ln1_layer_call_fn while saving (showing 5 of 2080). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cpm_saved_model/assets
# INFO:tensorflow:Assets written to: cpm_saved_model/assets

# %%
# !mkdir -p onnx
# !python -m tf2onnx.convert --saved-model cpm_saved_model --output onnx/cpm.zip --large_model --opset=13
# Out:
# 2021-10-12 16:31:26.635547: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-12 16:31:26.635574: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/conda/lib/python3.8/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2021-10-12 16:31:27.831891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-10-12 16:31:27.831915: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-12 16:31:27.831942: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (iZuf6fokcl2k1pwfopz0n4Z): /proc/driver/nvidia/version does not exist
# 2021-10-12 16:31:27.832198: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 16:31:27,842 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2021-10-12 16:31:45,968 - INFO - Signatures found in model: [serving_default].
# 2021-10-12 16:31:45,969 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2021-10-12 16:31:45,971 - INFO - Output names: ['output_1']
# 2021-10-12 16:31:46.122281: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2021-10-12 16:31:46.122457: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2021-10-12 16:31:46.578145: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 9077 nodes (8557), 11780 edges (11260), time = 272.039ms.
#   function_optimizer: function_optimizer did nothing. time = 9.448ms.
#
# 2021-10-12 16:32:35,050 - INFO - Using tensorflow=2.6.0, onnx=1.9.0, tf2onnx=1.9.2/0f28b7
# 2021-10-12 16:32:35,050 - INFO - Using opset <onnx, 13>
# 2021-10-12 16:33:51,010 - INFO - Computed 741 values for constant folding
# 2021-10-12 16:34:16,253 - INFO - folding node using tf type=Identity, name=Func/StatefulPartitionedCall/input/_1
# 2021-10-12 16:34:16,804 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,804 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,805 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,805 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,805 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,805 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer00/output/Tensordot/concat
# 2021-10-12 16:34:16,806 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer01/output/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,807 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer02/output/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,808 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer03/output/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer04/output/Tensordot/concat
# 2021-10-12 16:34:16,809 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer05/output/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,810 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer06/output/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,811 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer07/output/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer08/output/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,812 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer09/output/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,813 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer10/output/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer11/output/Tensordot/concat
# 2021-10-12 16:34:16,814 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer12/output/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,815 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer13/output/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,816 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer14/output/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer15/output/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,817 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer16/output/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,818 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer17/output/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer18/output/Tensordot/concat
# 2021-10-12 16:34:16,819 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer19/output/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,820 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer20/output/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,821 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer21/output/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer22/output/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,822 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer23/output/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,823 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer24/output/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer25/output/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,824 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer26/output/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,825 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer27/output/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer28/output/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,826 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer29/output/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,827 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer30/output/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/attention/key_layer/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/attention/value_layer/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/attention/query_layer/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/attention/context_projection_layer/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/intermediate/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=ConcatV2, name=StatefulPartitionedCall/gpt/layer31/output/Tensordot/concat
# 2021-10-12 16:34:16,828 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer00/activation/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer01/activation_1/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer02/activation_2/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer03/activation_3/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer04/activation_4/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer05/activation_5/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer06/activation_6/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer07/activation_7/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer08/activation_8/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,829 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer09/activation_9/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer10/activation_10/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer11/activation_11/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer12/activation_12/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer13/activation_13/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer14/activation_14/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer15/activation_15/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer16/activation_16/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,830 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer17/activation_17/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer18/activation_18/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer19/activation_19/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer20/activation_20/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer21/activation_21/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer22/activation_22/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer23/activation_23/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer24/activation_24/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,831 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer25/activation_25/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer26/activation_26/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer27/activation_27/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer28/activation_28/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer29/activation_29/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer30/activation_30/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Sqrt, name=StatefulPartitionedCall/gpt/layer31/activation_31/PartitionedCall/Sqrt
# 2021-10-12 16:34:16,832 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/position_embedding/ReadVariableOp
# 2021-10-12 16:34:16,839 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:16,839 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:16,839 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:16,855 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:16,855 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:16,881 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:16,881 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:16,897 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:16,897 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:16,913 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:16,913 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:16,914 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:16,914 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,108 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,109 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,298 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer00/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,298 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:17,298 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:17,298 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,325 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,325 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,351 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,351 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,377 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,377 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,402 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,402 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:17,403 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:17,403 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,595 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,595 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,782 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer01/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,783 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:17,783 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:17,783 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,809 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,809 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,835 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,835 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,862 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,862 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:17,889 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:17,889 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:17,890 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:17,890 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,079 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,079 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,268 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer02/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,268 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:18,268 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:18,268 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,295 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,296 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,322 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,323 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,349 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,350 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,376 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,376 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:18,377 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:18,377 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,568 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,568 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,756 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer03/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,756 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:18,756 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:18,756 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,783 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,783 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,810 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,810 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,836 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,836 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:18,863 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:18,863 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:18,863 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:18,863 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:19,054 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer04/intermediate/BiasAdd/ReadVariableOp
# ...
# 2021-10-12 16:34:29,510 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:29,511 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,538 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,538 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,564 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,564 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,591 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,591 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,618 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,618 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:29,618 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:29,618 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,808 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,809 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:29,998 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer26/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:29,998 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:29,999 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:29,999 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,026 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,026 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,052 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,052 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,078 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,079 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,106 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,106 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:30,106 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:30,106 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,296 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,296 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,486 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer27/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,486 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:30,486 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:30,486 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,513 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,514 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,542 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,542 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,568 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,569 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,595 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,595 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:30,596 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:30,596 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,785 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,786 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:30,975 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer28/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:30,975 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:30,975 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:30,975 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,002 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,003 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,029 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,029 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,057 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,057 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,083 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,084 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:31,084 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:31,084 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,273 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,274 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,463 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer29/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,464 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:31,464 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:31,464 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,491 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,492 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,520 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,520 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,546 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,547 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,572 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,573 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:31,573 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:31,573 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,762 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,763 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,952 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer30/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,952 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/LayerNorm_mlp_ln0/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:31,953 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/LayerNorm_mlp_ln0/batchnorm/ReadVariableOp
# 2021-10-12 16:34:31,953 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/key_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:31,981 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/key_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:31,981 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/value_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:32,008 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/value_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:32,008 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/query_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:32,035 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/query_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:32,035 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/context_projection_layer/Tensordot/ReadVariableOp
# 2021-10-12 16:34:32,062 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/attention/context_projection_layer/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:32,062 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/LayerNorm_mlp_ln1/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:32,062 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/LayerNorm_mlp_ln1/batchnorm/ReadVariableOp
# 2021-10-12 16:34:32,063 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/intermediate/Tensordot/ReadVariableOp
# 2021-10-12 16:34:32,252 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/intermediate/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:32,252 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/output/Tensordot/ReadVariableOp
# 2021-10-12 16:34:32,442 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/layer31/output/BiasAdd/ReadVariableOp
# 2021-10-12 16:34:32,442 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/LayerNorm_final_norm/batchnorm/mul/ReadVariableOp
# 2021-10-12 16:34:32,442 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/LayerNorm_final_norm/batchnorm/ReadVariableOp
# 2021-10-12 16:34:32,442 - INFO - folding node using tf type=Identity, name=StatefulPartitionedCall/gpt/Identity
# 2021-10-12 16:34:37,117 - INFO - Optimizing ONNX model
# 2021-10-12 16:36:30,567 - INFO - After optimization: Cast -514 (901->387), Concat -320 (545->225), Const -4223 (4765->542), Gather -256 (385->129), GlobalAveragePool +130 (0->130), Identity -266 (266->0), ReduceMean -130 (130->0), ReduceProd -384 (384->0), Reshape -129 (609->480), Shape -96 (257->161), Squeeze -33 (33->0), Transpose -225 (353->128), Unsqueeze -930 (995->65)
# 2021-10-12 16:36:51,459 - INFO -
# 2021-10-12 16:36:51,459 - INFO - Successfully converted TensorFlow model cpm_saved_model to ONNX
# 2021-10-12 16:36:51,460 - INFO - Model inputs: ['input_ids']
# 2021-10-12 16:36:51,460 - INFO - Model outputs: ['output_1']
# 2021-10-12 16:36:51,461 - INFO - Zipped ONNX model is saved at onnx/cpm.onnx. Unzip before opening in onnxruntime.

# %%
# to unzip it

# %%
import onnx
from onnxruntime.quantization import quantize_dynamic, QuantType

# %%
# !mkdir -p onnx_q

# %%
quantized_model = quantize_dynamic(
    './onnx/__MODEL_PROTO.onnx',
    './onnx_q/cpm.onnx',
    weight_type=QuantType.QUInt8,
    use_external_data_format=True
)
